# %%
import pandas

df = pandas.read_csv("../webscraper/course_data/AAS/testclass.csv")

# %%
df.head()
# Out:
#                  Sections Found Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  AAS-African American Studies        NaN        NaN        NaN        NaN
# 1                        Select        CRN       Subj       Crse        Sec
# 2                             C      15897        AAS       2020          1
# 3                            NR      15898        AAS       2020          2
# 4                            NR      15899        AAS       2020          3
#
#   Unnamed: 5 Unnamed: 6                                         Unnamed: 7  \
# 0        NaN        NaN                                                NaN
# 1        Cmp       Cred                                              Title
# 2        24M          3  Themes in Literature and Culture:The African A...
# 3        24M          3  Themes in Literature and Culture:The African A...
# 4        24M          3  Themes in Literature and Culture:The African A...
#
# ...
