# %%
import pandas

df = pandas.read_csv("../webscraper/course_data/csv/GERM.csv")

# %%
from IPython.display import display, HTML
display(df)
# Out:
#    Sections Found Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     GERM-German        NaN        NaN        NaN        NaN        NaN
# 1          Select        CRN       Subj       Crse        Sec        Cmp
# 2              NR      10616       GERM       1010          1        24M
# 3              NR      10617       GERM       1010          2        24M
# 4              NR      10618       GERM       1020          1        24M
# 5              NR      16528       GERM       2010          1        24M
# 6              NR      13531       GERM       2020          1        24M
# 7              NR      13434       GERM       3000          1        24M
# 8              NR      15773       GERM       3020          1        24M
# 9              NR      17062       GERM       3030          1        24M
# 10              C      17397       GERM       3910        S01        24M
# 11             NR      16530       GERM       4010          1        24M
# ...
