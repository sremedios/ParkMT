# %%
import pandas

df = pandas.read_csv("../webscraper/course_data/csv/HIST.csv")

# %%
df
# Out:
#                   Sections Found Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0    HIST-History (MTSU & TN eC)        NaN        NaN        NaN        NaN
# 1                         Select        CRN       Subj       Crse        Sec
# 2                             NR      16595       HIST       1010          1
# 3                             NR      13256       HIST       1010          2
# 4                             NR      16596       HIST       1020        H01
# 5                              C      11216       HIST       1110          1
# 6                             NR      11217       HIST       1110          2
# 7                             NR      11218       HIST       1110          3
# 8                             NR      11219       HIST       1110        D01
# 9                              C      11937       HIST       1110        R50
# 10                            NR      14284       HIST       1120          1
# ...

# %%
df.ix[4,8]
# Out:
# 'TR'
